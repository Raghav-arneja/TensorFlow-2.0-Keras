# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# #data loading

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)

# %%
# list the directories

zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

# %% [markdown]
# #understanding the data

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# #setting model parameters

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# #data augmentation

# %%
  # This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # flipping the image horizontally

# %%
image_gen = ImageDataGenerator(rescale = 1./255, horizontal_flip= True)

train_data_gen = image_gen.flow_from_directory (batch_size = BATCH_SIZE,
                                               directory = train_dir,
                                               shuffle = True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2000 images belonging to 2 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #rotating the image

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=60)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2000 images belonging to 2 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #applying zoom

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2000 images belonging to 2 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #putting it all together

# %%
image_gen_train = ImageDataGenerator(
      rescale=1./255,
      rotation_range=60,
      width_shift_range=0.2,
      height_shift_range=0.2,
      shear_range=0.2,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')

train_data_gen = image_gen_train.flow_from_directory(batch_size=BATCH_SIZE,
                                                     directory=train_dir,
                                                     shuffle=True,
                                                     target_size=(IMG_SHAPE,IMG_SHAPE),
                                                     class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #creating validation data generator

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=BATCH_SIZE,
                                                 directory=validation_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# #model creation

# %%
# defining the model
model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(32, (3,3), activation= 'relu', input_shape = (150,150,3)),
                             tf.keras.layers.MaxPooling2D(2,2),

                             tf.keras.layers.Conv2D(64, (3,3), activation= 'relu'),
                             tf.keras.layers.MaxPooling2D(2,2),

                             tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                             tf.keras.layers.MaxPooling2D(2,2),

                             tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                             tf.keras.layers.MaxPooling2D(2,2),

                             tf.keras.layers.Dropout(0.5),
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(512, activation= 'relu'),
                             tf.keras.layers.Dense(2, activation = 'softmax')
])

# %%
# for a single output layer we can use
# tf.keras.layers.Dense(1, activation = 'sigmoid')
# model.compile(optimizer = 'adam', loss = tf.keras.losses.binary_crossentropy, metrics = ['accuracy'])

# %% [markdown]
# #compile the model

# %%
model.compile(optimizer= 'adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True),
              metrics = ['accuracy'])

# %%
# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch = int(np.ceil(total_train/ float(BATCH_SIZE))),
    epochs = EPOCHS,
    validation_data = val_data_gen,
    validation_steps = int(np.ceil(total_val/ float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 15s 742ms/step - loss: 0.6958 - accuracy: 0.4950 - val_loss: 0.6910 - val_accuracy: 0.5010
# Epoch 2/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.6941 - accuracy: 0.5140 - val_loss: 0.6914 - val_accuracy: 0.5000
# Epoch 3/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.6883 - accuracy: 0.5410 - val_loss: 0.6835 - val_accuracy: 0.5410
# Epoch 4/100
# 20/20 [==============================] - 15s 773ms/step - loss: 0.6756 - accuracy: 0.5785 - val_loss: 0.6428 - val_accuracy: 0.6140
# Epoch 5/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.6628 - accuracy: 0.6110 - val_loss: 0.6287 - val_accuracy: 0.6570
# Epoch 6/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.6470 - accuracy: 0.6175 - val_loss: 0.6196 - val_accuracy: 0.6470
# Epoch 7/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.6358 - accuracy: 0.6470 - val_loss: 0.5987 - val_accuracy: 0.7010
# Epoch 8/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.6413 - accuracy: 0.6430 - val_loss: 0.6583 - val_accuracy: 0.6050
# Epoch 9/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.6453 - accuracy: 0.6250 - val_loss: 0.6282 - val_accuracy: 0.6370
# Epoch 10/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.6237 - accuracy: 0.6675 - val_loss: 0.5869 - val_accuracy: 0.6980
# Epoch 11/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.5954 - accuracy: 0.6940 - val_loss: 0.6206 - val_accuracy: 0.6530
# Epoch 12/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.6097 - accuracy: 0.6790 - val_loss: 0.5835 - val_accuracy: 0.7080
# Epoch 13/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5956 - accuracy: 0.6985 - val_loss: 0.5699 - val_accuracy: 0.7220
# Epoch 14/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.6200 - accuracy: 0.6670 - val_loss: 0.5841 - val_accuracy: 0.7060
# Epoch 15/100
# 20/20 [==============================] - 16s 776ms/step - loss: 0.6062 - accuracy: 0.6855 - val_loss: 0.5906 - val_accuracy: 0.7060
# Epoch 16/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5982 - accuracy: 0.6925 - val_loss: 0.5796 - val_accuracy: 0.7200
# Epoch 17/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5931 - accuracy: 0.6955 - val_loss: 0.5616 - val_accuracy: 0.7430
# Epoch 18/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.5942 - accuracy: 0.6980 - val_loss: 0.5531 - val_accuracy: 0.7480
# Epoch 19/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5889 - accuracy: 0.7105 - val_loss: 0.5603 - val_accuracy: 0.7320
# Epoch 20/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.5865 - accuracy: 0.7065 - val_loss: 0.5675 - val_accuracy: 0.7330
# Epoch 21/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5776 - accuracy: 0.7140 - val_loss: 0.5714 - val_accuracy: 0.7290
# Epoch 22/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.5843 - accuracy: 0.7135 - val_loss: 0.5721 - val_accuracy: 0.7320
# Epoch 23/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5811 - accuracy: 0.7125 - val_loss: 0.5416 - val_accuracy: 0.7570
# Epoch 24/100
# 20/20 [==============================] - 15s 775ms/step - loss: 0.5717 - accuracy: 0.7230 - val_loss: 0.5442 - val_accuracy: 0.7680
# Epoch 25/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5831 - accuracy: 0.7090 - val_loss: 0.5490 - val_accuracy: 0.7580
# Epoch 26/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5721 - accuracy: 0.7235 - val_loss: 0.5404 - val_accuracy: 0.7600
# Epoch 27/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5628 - accuracy: 0.7425 - val_loss: 0.5933 - val_accuracy: 0.6940
# Epoch 28/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5742 - accuracy: 0.7140 - val_loss: 0.5484 - val_accuracy: 0.7530
# Epoch 29/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5665 - accuracy: 0.7290 - val_loss: 0.5430 - val_accuracy: 0.7620
# Epoch 30/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5475 - accuracy: 0.7450 - val_loss: 0.5515 - val_accuracy: 0.7410
# Epoch 31/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5562 - accuracy: 0.7395 - val_loss: 0.5417 - val_accuracy: 0.7600
# Epoch 32/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5629 - accuracy: 0.7315 - val_loss: 0.5236 - val_accuracy: 0.7880
# Epoch 33/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.5500 - accuracy: 0.7465 - val_loss: 0.5340 - val_accuracy: 0.7670
# Epoch 34/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.5615 - accuracy: 0.7330 - val_loss: 0.5388 - val_accuracy: 0.7640
# Epoch 35/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5620 - accuracy: 0.7350 - val_loss: 0.5886 - val_accuracy: 0.6990
# Epoch 36/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5518 - accuracy: 0.7435 - val_loss: 0.5371 - val_accuracy: 0.7590
# Epoch 37/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5518 - accuracy: 0.7490 - val_loss: 0.5255 - val_accuracy: 0.7740
# Epoch 38/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5558 - accuracy: 0.7370 - val_loss: 0.5379 - val_accuracy: 0.7670
# Epoch 39/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5612 - accuracy: 0.7310 - val_loss: 0.5699 - val_accuracy: 0.7200
# Epoch 40/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.5502 - accuracy: 0.7490 - val_loss: 0.5325 - val_accuracy: 0.7710
# Epoch 41/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5541 - accuracy: 0.7480 - val_loss: 0.5274 - val_accuracy: 0.7720
# Epoch 42/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5346 - accuracy: 0.7655 - val_loss: 0.5178 - val_accuracy: 0.7870
# Epoch 43/100
# 20/20 [==============================] - 15s 758ms/step - loss: 0.5378 - accuracy: 0.7665 - val_loss: 0.5446 - val_accuracy: 0.7560
# Epoch 44/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5447 - accuracy: 0.7550 - val_loss: 0.5334 - val_accuracy: 0.7650
# Epoch 45/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.5492 - accuracy: 0.7555 - val_loss: 0.5181 - val_accuracy: 0.7850
# Epoch 46/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5416 - accuracy: 0.7530 - val_loss: 0.5279 - val_accuracy: 0.7750
# Epoch 47/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5413 - accuracy: 0.7590 - val_loss: 0.5366 - val_accuracy: 0.7600
# Epoch 48/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.5432 - accuracy: 0.7595 - val_loss: 0.5258 - val_accuracy: 0.7680
# Epoch 49/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5297 - accuracy: 0.7655 - val_loss: 0.5531 - val_accuracy: 0.7480
# Epoch 50/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5403 - accuracy: 0.7575 - val_loss: 0.5107 - val_accuracy: 0.7960
# Epoch 51/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5241 - accuracy: 0.7720 - val_loss: 0.5085 - val_accuracy: 0.7900
# Epoch 52/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5276 - accuracy: 0.7725 - val_loss: 0.5283 - val_accuracy: 0.7720
# Epoch 53/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.5390 - accuracy: 0.7595 - val_loss: 0.5642 - val_accuracy: 0.7210
# Epoch 54/100
# 20/20 [==============================] - 15s 773ms/step - loss: 0.5311 - accuracy: 0.7715 - val_loss: 0.5379 - val_accuracy: 0.7640
# Epoch 55/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.5285 - accuracy: 0.7725 - val_loss: 0.5184 - val_accuracy: 0.7790
# Epoch 56/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5208 - accuracy: 0.7780 - val_loss: 0.5806 - val_accuracy: 0.7200
# Epoch 57/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.5306 - accuracy: 0.7675 - val_loss: 0.5303 - val_accuracy: 0.7700
# Epoch 58/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5289 - accuracy: 0.7765 - val_loss: 0.5100 - val_accuracy: 0.7910
# Epoch 59/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.5269 - accuracy: 0.7785 - val_loss: 0.5138 - val_accuracy: 0.7890
# Epoch 60/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.5128 - accuracy: 0.7895 - val_loss: 0.5191 - val_accuracy: 0.7870
# Epoch 61/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.5262 - accuracy: 0.7770 - val_loss: 0.4974 - val_accuracy: 0.8090
# Epoch 62/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5143 - accuracy: 0.7880 - val_loss: 0.5341 - val_accuracy: 0.7610
# Epoch 63/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.5208 - accuracy: 0.7795 - val_loss: 0.5290 - val_accuracy: 0.7660
# Epoch 64/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.5298 - accuracy: 0.7725 - val_loss: 0.5248 - val_accuracy: 0.7770
# Epoch 65/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.5225 - accuracy: 0.7805 - val_loss: 0.5067 - val_accuracy: 0.8000
# Epoch 66/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.5135 - accuracy: 0.7900 - val_loss: 0.5206 - val_accuracy: 0.7840
# Epoch 67/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5164 - accuracy: 0.7885 - val_loss: 0.4998 - val_accuracy: 0.8080
# Epoch 68/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5111 - accuracy: 0.7830 - val_loss: 0.5005 - val_accuracy: 0.8060
# Epoch 69/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5077 - accuracy: 0.7955 - val_loss: 0.5022 - val_accuracy: 0.7960
# Epoch 70/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5207 - accuracy: 0.7805 - val_loss: 0.5142 - val_accuracy: 0.7850
# Epoch 71/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5088 - accuracy: 0.7925 - val_loss: 0.5040 - val_accuracy: 0.8000
# Epoch 72/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5043 - accuracy: 0.8010 - val_loss: 0.5113 - val_accuracy: 0.7840
# Epoch 73/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.5089 - accuracy: 0.7970 - val_loss: 0.5032 - val_accuracy: 0.7970
# Epoch 74/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.4971 - accuracy: 0.8090 - val_loss: 0.5087 - val_accuracy: 0.7920
# Epoch 75/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.5003 - accuracy: 0.8025 - val_loss: 0.5167 - val_accuracy: 0.7840
# Epoch 76/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5214 - accuracy: 0.7790 - val_loss: 0.5064 - val_accuracy: 0.7890
# Epoch 77/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.5312 - accuracy: 0.7660 - val_loss: 0.5706 - val_accuracy: 0.7250
# Epoch 78/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5144 - accuracy: 0.7910 - val_loss: 0.4924 - val_accuracy: 0.8100
# Epoch 79/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.5101 - accuracy: 0.7930 - val_loss: 0.5037 - val_accuracy: 0.7900
# Epoch 80/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.5113 - accuracy: 0.7930 - val_loss: 0.4926 - val_accuracy: 0.8090
# Epoch 81/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.4985 - accuracy: 0.8040 - val_loss: 0.5095 - val_accuracy: 0.7950
# Epoch 82/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5048 - accuracy: 0.8010 - val_loss: 0.5003 - val_accuracy: 0.8010
# Epoch 83/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.5183 - accuracy: 0.7785 - val_loss: 0.5019 - val_accuracy: 0.7950
# Epoch 84/100
# 20/20 [==============================] - 15s 761ms/step - loss: 0.5131 - accuracy: 0.7915 - val_loss: 0.5156 - val_accuracy: 0.7760
# Epoch 85/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.4977 - accuracy: 0.8090 - val_loss: 0.5023 - val_accuracy: 0.7920
# Epoch 86/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.4895 - accuracy: 0.8155 - val_loss: 0.5155 - val_accuracy: 0.7820
# Epoch 87/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.4974 - accuracy: 0.8025 - val_loss: 0.5042 - val_accuracy: 0.7970
# Epoch 88/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.4913 - accuracy: 0.8125 - val_loss: 0.5173 - val_accuracy: 0.7850
# Epoch 89/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5129 - accuracy: 0.7880 - val_loss: 0.5360 - val_accuracy: 0.7670
# Epoch 90/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.4987 - accuracy: 0.8130 - val_loss: 0.4959 - val_accuracy: 0.8110
# Epoch 91/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.4847 - accuracy: 0.8240 - val_loss: 0.5069 - val_accuracy: 0.7950
# Epoch 92/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.4863 - accuracy: 0.8240 - val_loss: 0.5323 - val_accuracy: 0.7790
# Epoch 93/100
# 20/20 [==============================] - 16s 777ms/step - loss: 0.4988 - accuracy: 0.8075 - val_loss: 0.4988 - val_accuracy: 0.8030
# Epoch 94/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.4964 - accuracy: 0.8055 - val_loss: 0.5232 - val_accuracy: 0.7770
# Epoch 95/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.4950 - accuracy: 0.8085 - val_loss: 0.5027 - val_accuracy: 0.8090
# Epoch 96/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.4858 - accuracy: 0.8130 - val_loss: 0.4948 - val_accuracy: 0.8170
# Epoch 97/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.4884 - accuracy: 0.8145 - val_loss: 0.5075 - val_accuracy: 0.7940
# Epoch 98/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.4895 - accuracy: 0.8105 - val_loss: 0.5037 - val_accuracy: 0.8000
# Epoch 99/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.4769 - accuracy: 0.8300 - val_loss: 0.4834 - val_accuracy: 0.8210
# Epoch 100/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.4960 - accuracy: 0.8110 - val_loss: 0.5150 - val_accuracy: 0.7860

# %% [markdown]
# #visualizing the results of the training

# %%
  acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
